# %% [markdown]
# DIA 2...

# %%
#agregamos la variable asignable para la temperatura
tempe_ratura = int(input('cual es la temperatura de hoy'))

#primer condicionante
if tempe_ratura <= -10 and  tempe_ratura <=18:
    print('fresquete, mas que el corazon de ella')

#segunda condicionante
elif tempe_ratura >= 19 and  tempe_ratura <= 30:
    print('calorcito, jau tefri')

#tercera condicionante
elif tempe_ratura <= 31 and tempe_ratura <=45:
     print('que calor')

#cuarta condicionante
else:
    print('hakuro vamo a morirno')
# Out:
# hakuro vamo a morirno

# %%
#asignar contrasenha correcta:
password_real = 123456
while True:
    pasword_solicitada = int(input('holaquetal'))
    if password_real != pasword_solicitada:
         input('pasword_solicitada')
    else password_real == pasword_solicitada:
        print('contrasena correcta')
    break
# Out:
#   Cell In[90], line 7
#     else password_real == pasword_solicitada:
#          ^
# SyntaxError: expected ':'

# %% [markdown]
# LISTAS - CHALLENGE 1

# %%
#definimos la lista

hardware = ["memorias" , 'procesadores' , "almacenamiento" , "fuentes" , "gabinetes"]
print(hardware)
#agregamos un elemento al final de la lista

hardware.append ("monitores")
print(hardware)
# Out:
# ['memorias', 'procesadores', 'almacenamiento', 'fuentes', 'gabinetes']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[96], line 7
#       4 print(hardware)
#       5 #agregamos un elemento al final de la lista
# ----> 7 hardware.append (monitores)
#       8 print(hardware)
#
# NameError: name 'monitores' is not defined

# %% [markdown]
# bucle iterativo

# %%
for i in range(10):
    resultado = i * 2
    print(f"Iteración {i}: {resultado}")
# Out:
# Iteración 0: 0
# Iteración 1: 2
# Iteración 2: 4
# Iteración 3: 6
# Iteración 4: 8
# Iteración 5: 10
# Iteración 6: 12
# Iteración 7: 14
# Iteración 8: 16
# Iteración 9: 18

# %%
#creacion de lista

marca = ["samsung" , "kia" , "corsair" , "gibson"]

for marca in marca:
    if len(marca) >=6:
        print(marca)
# Out:
# samsung
# corsair
# gibson

# %%
frase_1 = input(print())
for frase_1 in frase_1:
    if len(o):
        print(frase_1)
