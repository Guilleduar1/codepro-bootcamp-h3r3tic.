# %% [markdown]
# DIA 4 CODEPRO

# %%
datos_usuario = {"nombre": "ejemplo1", "edad": "numero anhos", "sexo": "genero", "telefono": "numerodecel", "email" : "alguien@alguien.com"}

print(datos_usuario) 

#volver a practicar
# Out:
# {'nombre': 'ejemplo1', 'edad': 'numero anhos', 'sexo': 'genero', 'telefono': 'numerodecel', 'email': 'alguien@alguien.com'}

# %%
#paso 1 asignar un diccionario
tarjeta_personal = {'nombre': 'usuario', "apellido": "usuario2", "edad": "anhos", "Cargo" : "ingrese_su_cargo"}
print(tarjeta_personal)

#paso 2: agregar nuevos datos

tarjeta_personal["nombre"] = input('ingrese su nombre')
print(tarjeta_personal)

#falta terminar el codigo y hacerlo funcionar
# Out:
# {'nombre': 'usuario', 'apellido': 'usuario2', 'edad': 'anhos', 'Cargo': 'ingrese_su_cargo'}
# {'nombre': 'guille', 'apellido': 'usuario2', 'edad': 'anhos', 'Cargo': 'ingrese_su_cargo'}

# %% [markdown]
# PROGRAMACION ORIENTADA A OBJETOS

# %%
#paso 1 creamos una clase
class Lobo:
    especie = "canino"

    #falta terminar este ejercicio"

# %%
class Perro:
    especie = "canina"

    #falta terminar el codigo, el pseudocodigo ya esta parcialmente hecho

# %% [markdown]
# para este challenge debo practicar mas

# %%
#Crear dos personajes de una historia que se representen a traves de clases. Ejemplo: Un hereo y un villano.
#Cada personaje debe tener poderes o acciones diferentes. Y deben presentarse en una frase.
#Ejemplo: Yo me llamo pepito y tengo super fuerza
#Ejemplo: Yo me llamo juanito y puedo volar

class Superhumanos:
    tipo1 = 'Villano'

def __init__ (self, nombre, habilidad, superpoder)
    self.nombre = 'Asmodeo'
    self.habilidad = 'atemorizar'
    self.superpoder = 'escupir acido'

def
