# %%
print('hola mundo')

# %%
# orden de ejecución:
fruta = 'naranja'
print (fruta)

cantidad_de_frutas = 4
print (cantidad_de_frutas)

fruta = "banana"
print (fruta)

# %% [markdown]
# ##Tipos de datos

# %%
edad = 28 # --> integer
altura = 1.80 # --> float
nombre = "Maggi" # --> string
feliz = True # bool
print(edad)
print (altura) 
print (nombre)
print (feliz)
print(edad, altura, nombre, feliz)

# %% [markdown]
# #challenge_1

# %%
nombre = "Guille"
edad = 28
ciudad = "lambare"
print ("soy" , nombre , "tengo" , edad, "y vivo en", ciudad)

# %% [markdown]
# challenge_2_codepro5.0

# %%
#asignacion de valor o dato para cada variable de fruta (cantidad)
cantidad_de_manzanas = 29
cantidad_de_naranjas = 38

#ahora sumamos

cantidad_de_frutas = cantidad_de_manzanas + cantidad_de_naranjas
print (cantidad_de_frutas)

#resta agregando una nueva variable y pudiendo utilizarlo con las variables anteriores
frutas_vendidas = 45
frutas_restantes = cantidad_de_frutas - frutas_vendidas
print (frutas_restantes)

# %% [markdown]
# challenge_3 codepro5.0

# %%
nombre = "Adilson"
apellido = "Alvarenga"

#uniendo strigs en uno solo

print('Hola me llamo', nombre , apellido , "Mucho gusto" )
# Out:
# Hola me llamo adilson Alvarenga Mucho gusto

# %% [markdown]
# input = sirve para solicitar datos al usuario

# %%
#el input sirve para que el progrma le haga una pregunta al usuario y guarde lo que este responde en el teclado

nombre = input("Escribe tu nombre")
print(nombre)
# Out:
# Guille

# %%
#solicitar al usuario un producto
producto = input("que producto deseas?")
print(producto)

#solicitar cantidad de ese producto

cantidad_de_productos = input("Que cantidad de producto deseas?")
print(cantidad_de_productos)

print(f'El usuario quiere una {producto} en {cantidad_de_productos} cantidades')
# Out:
# applewatch
# 4
# El usuario quiere una applewatch en 4 cantidades

# %% [markdown]
# Ver tipos de datos

# %%
edad = 19
print(type (edad))

nombre = 'Claudia'
print(type(nombre))

temperatura = 36.5
print (type(temperatura))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
edad = input("cuantos anhos tienes?")
print(type(edad))

cantidad_de_anhos = int(edad)
print(type(cantidad_de_anhos))
# Out:
# <class 'str'>
# <class 'int'>

# %% [markdown]
# Challenge_4 codepro5.0

# %%
#crear variables cuyo valor pueda ser agregado por el usuario
numero1 = int(input("ingresa el primer numero"))
print(numero1)  

numero2 = int(input("ingresa el segundo numero"))
print(numero2)

numero_total = numero1 + numero2 
print(numero_total)

#queda repasar y revisar el porque no ejecuta como debe
# Out:
# 10
# 100
# 110

# %% [markdown]
# Funciones

# %%
#algoritmos
#aqui definimos la funcion

def preparar_sandwich():
    print ("preparar un sandwich")

    print("ya el sandwich esta casi listo")
#aqui termina la funcion

#llamar a la funcion
preparar_sandwich()
# Out:
# preparar un sandwich
# ya el sandwich esta casi listo

# %%
#aqui definiendo las ordenes de la funcion
def alimentar_al_gato():
    print("tomar el plato del gato del piso")
    print("dejar el plato en la mesa")
    print("tomar la bolsa de alimentos")
    print("abrir la bolsa de alimentos")
    print("servir el alimento en el plato del gato")
    print("tomar el plato de la mesa")
    print("bajar el plato del gato en el piso") 

#aqui llamamos a la funcion
alimentar_al_gato()
alimentar_al_gato()
alimentar_al_gato()
# Out:
# tomar el plato del gato del piso
# dejar el plato en la mesa
# tomar la bolsa de alimentos
# abrir la bolsa de alimentos
# servir el alimento en el plato del gato
# tomar el plato de la mesa
# bajar el plato del gato en el piso
# tomar el plato del gato del piso
# dejar el plato en la mesa
# tomar la bolsa de alimentos
# abrir la bolsa de alimentos
# servir el alimento en el plato del gato
# tomar el plato de la mesa
# bajar el plato del gato en el piso
# tomar el plato del gato del piso
# dejar el plato en la mesa
# tomar la bolsa de alimentos
# abrir la bolsa de alimentos
# servir el alimento en el plato del gato
# tomar el plato de la mesa
# bajar el plato del gato en el piso

# %% [markdown]
# #parametros y argumentos

# %% [markdown]
# #existen parametros globales y locales, los globales son los que se establezcan fuera de nuestra funcion, mientras que las locales son las que asignamos dentro de nuestra funcion y no funcionaran fuera de el
